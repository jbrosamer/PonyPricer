# %%
# %load_ext autoreload
# %autoreload 2
# %cd ~/PonyPricer/
# %matplotlib inline
# %run cleandata.py

import re
import math
import requests
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.cross_validation import train_test_split
from sklearn.cross_validation import KFold
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import metrics
from sklearn import linear_model
from sklearn import isotonic
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from model import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /Users/jbrosamer/PonyPricer
# opening /Users/jbrosamer/PonyPricer/BatchArea/AllGreatLakesUSAAds.p
# N Rows /Users/jbrosamer/PonyPricer/BatchArea/AllGreatLakesUSAAds.p 32226
# Total rows 32226 Line  66
# Total rows 32226 Line  166
# Total rows 32226 Line  118
# Total rows 5258 Line  120
# Total rows 4848 Line  122
# Total rows 4842 Line  125
# Total rows 4842 Line  132
# Total rows 4842 Line  136
# Total rows 4842 Line  168
# N rows 4842

# %%
from model import *
path="/Users/jbrosamer/PonyPricer/BatchArea/GreatLakesConcatAds.p"
df_test = all_data()
df = df_test.copy()
df = clean_col(df)
df = encode(df)
b = Model(df)
b.split()
b.kfold_cv(n_folds=2)
b.plot_results()
#df=b.cross_val_cols()
# Out:
# df.columns Index([u'id', u'breed', u'price', u'color', u'age', u'zip', u'temp',
#        u'warmblood', u'sold', u'soldhere', u'forsale', u'forlease',
#        u'registered', u'skills', u'desc', u'gender', u'inches', u'lnprice',
#        u'breedGroup', u'dressage', u'hunt', u'jump', u'event', u'prospect',
#        u'import', u'compet', u'video'],
#       dtype='object')
# Score 0.327201138344
# Score 0.315504158271
# Abs Median Error: 3492.4300427
# Abs Percent Error: 0.473442335882
# Mean RMSE: 10571.6029855
# R2 0.321352648308
# Line fit m:0.363208 b:5.709531

# %%
b.kfold_cv()
# Out:
# Score 0.356817500743
# Score 0.327817647401
# Score 0.353937423094
# Abs Median Error: 3461.82160539
# Abs Percent Error: 0.461705228148
# Mean RMSE: 10383.579424
# R2 0.29008351574

# %%
gbr=b.makeModel()
b.plotFeatures()
# Out:
# Feature ranking:
# 1. feature 0 (0.301270)
# 2. feature 4 (0.253601)
# 3. feature 2 (0.191275)
# 4. feature 5 (0.117522)
# 5. feature 3 (0.103147)
# 6. feature 1 (0.033186)

# %%
b.plotPartial(8)
# Out:
# features [0 4 2 5 3 1]
# FeatureNames ['age', 'gender', 'inches', 'color', 'breed', 'breedGroup', 'lnprice']
# ________________________________________________________________________________
# Custom 3d plot via ``partial_dependence``

# %%
features=final_cols[:-1]
medians=list()
means=list()
pf=predCVDataframe()
gpDict=dict()
for f in features:
    gpBy=pf.groupby(pf[f])['perDiff'].median().sort_values(ascending=False)
    gpDict[f]=gpBy
# Out:
# df.columns Index([u'id', u'breed', u'price', u'color', u'age', u'zip', u'temp',
#        u'warmblood', u'sold', u'soldhere', u'forsale', u'forlease',
#        u'registered', u'skills', u'gender', u'inches', u'lnprice',
#        u'breedGroup', u'dressage', u'hunter', u'jumper', u'eventing'],
#       dtype='object')

# %%
gpDict['breedGroup']
# Out:
# breedGroup
# TB           0.511587
# Mustang      0.506515
# Gaited       0.423408
# Warmblood    0.418775
# Arab         0.414890
# Pony         0.409198
# Quarter      0.400332
# Other        0.385467
# Spanish      0.383440
# Draft        0.355582
# Mule         0.257158
# Name: perDiff, dtype: float64

# %%
plt.style.use('ggplot')
df = df_test.copy()
df = clean_col(df)
idx = df.loc[df['price']>100000,:].index
#df = df.drop(idx, axis = 0)
df_temp = df[['age','inches', 'gender', 'lnprice']]
plot = sns.pairplot(df_temp, hue = 'gender', diag_kind='kde')
# Out:
# df.columns Index([u'id', u'breed', u'price', u'color', u'age', u'zip', u'temp',
#        u'warmblood', u'sold', u'soldhere', u'forsale', u'forlease',
#        u'registered', u'skills', u'gender', u'inches', u'lnprice',
#        u'breedGroup', u'dressage', u'hunter', u'jumper', u'eventing'],
#       dtype='object')
