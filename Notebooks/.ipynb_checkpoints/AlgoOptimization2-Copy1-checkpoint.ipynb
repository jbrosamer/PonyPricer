# %%
# %load_ext autoreload
# %autoreload 2
# %cd ~/PonyPricer/
# %matplotlib inline
# %run cleandata.py

import re
import math
import requests
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.cross_validation import train_test_split
from sklearn.cross_validation import KFold
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import metrics
from sklearn import linear_model
from sklearn import isotonic
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from model import *
# Out:
# /Users/jbrosamer/PonyPricer
# opening /Users/jbrosamer/PonyPricer/BatchArea/AllGreatLakesUSAAds.p
# N Rows /Users/jbrosamer/PonyPricer/BatchArea/AllGreatLakesUSAAds.p 32226
# Total rows 32226 Line  66
# Total rows 32226 Line  170
# Total rows 32226 Line  119
# Total rows 5258 Line  121
# Total rows 4848 Line  123
# Total rows 4842 Line  126
# Total rows 4842 Line  133
# Skills 4H
# Skills 5-Panel DNA Test N-N
# Skills Advanced Rider Recommended
# Skills Agility
# Skills All Around
# Skills Baroque Horse
# Skills Barrel Racing
# Skills Beginner-Safe Horse
# Skills Breeders Trust
# Skills Bridle Horse
# Skills Broodmare
# Skills Broodmare Only
# Skills Calf Roping
# Skills Champion
# Skills Champion Pedigree
# Skills Color Tested
# Skills Companion Only
# Skills Country English Pleasure
# Skills Cowboy Mounted Shooting
# Skills Cowboy Racing
# Skills Cowhorse
# Skills Cutting
# Skills Double Registered
# Skills Double Registered AQHA-APHA
# Skills Draft
# Skills Dressage
# Skills Drill Team
# Skills Driving
# Skills Endurance Riding
# Skills English Pleasure
# Skills Eventing
# Skills Field Trials
# Skills Foundation Bred
# Skills Foxhunter
# Skills Futurity Eligible
# Skills GBED N-G
# Skills GBED N-N
# Skills Guard Donkey
# Skills Gun-Safe Hunting Horse
# Skills Gymkhana
# Skills Hackamore Horse
# Skills Halter
# Skills Harness
# Skills Harness Racing
# Skills Hazing
# Skills HERDA N-Hrd
# Skills HERDA N-N
# Skills Heterozygous
# Skills High-Percentage Color Producer
# Skills High-Percentage Cropout Producer
# Skills High-Percentage Dun Factor Producer
# Skills Homozygous
# Skills Homozygous Black
# Skills Homozygous Roan
# Skills Homozygous Tobiano
# Skills Horse Ball
# Skills Horsemanship
# Skills Hunt Seat Equitation
# Skills Hunter
# Skills Hunter Under Saddle
# Skills Husband-Safe Horse
# Skills HYPP N-H
# Skills HYPP N-N
# Skills Incentive Fund
# Skills Intermediate Rider Recommended
# Skills Jumping
# Skills Kentucky Breeders Incentive Program
# Skills Kid-Friendly Family Horse
# Skills Lesson Horse
# Skills Longe Line
# Skills Money Winner
# Skills Mounted Games
# Skills Mounted Patrol
# Skills Mounted Police
# Skills Native Costume
# Skills Natural Horsemanship Training
# Skills No Vices
# Skills NRBC Eligible
# Skills NRBC Enrolled
# Skills NRCHA Subscribed Stallion
# Skills NRHA Futurity-Derby Nominated
# Skills NRHA Sire and Dam Program
# Skills Nurse Mare
# Skills Orphan Foal
# Skills Pacing Gait
# Skills Pack Horse
# Skills Parades
# Skills Park
# Skills Playday
# Skills Pleasure Driving
# Skills PMU Foal
# Skills Point Earner
# Skills Pole Bending
# Skills Polo
# Skills Polocrosse
# Skills Pony Breed
# Skills Pony Club
# Skills Racing
# Skills Racing, Retired Racehorse
# Skills Racking Gait
# Skills Ranch Horse Riding
# Skills Ranch Sorting
# Skills Ranch Versatility
# Skills Ranch Work
# Skills Recipient Broodmare
# Skills Register of Merit
# Skills Reining
# Skills Reining Cowhorse Cutting
# Skills Rescue Horse
# Skills Ridden English
# Skills Ridden Western
# Skills Rider Level: Amateur
# Skills Rider Level: Novice
# Skills Rider Level: Open
# Skills Rodeo Bronc
# Skills Rodeo Pickup Horse
# Skills Rodeo Queen Horse
# Skills Roping
# Skills Roping, All Around
# Skills Saddle Seat
# Skills School
# Skills Schoolmaster
# Skills Show Experience
# Skills Show Hack
# Skills Show Winner
# Skills Showmanship at Halter
# Skills Sidesaddle
# Skills Sporthorse
# Skills Stallion, Breeding
# Skills Started Under Saddle
# Skills Steer Roping
# Skills Steer Wrestling
# Skills Superior Award
# Skills Team Driving
# Skills Team Penning
# Skills Team Roping
# Skills Team Roping Head Horse
# Skills Team Roping Heel Horse
# Skills Therapeutic Riding
# Skills Three-In-One Package
# Skills Trail Class Competition
# Skills Trail Riding, Competitive
# Skills Trail Riding, Recreational
# Skills Trick Horse
# Skills Triple Registered
# Skills Turnback Horse
# Skills Two-In-One Package
# Skills Two-Rein Horse
# Skills Vaulting
# Skills Weanling
# Skills Western Dressage
# Skills Western Pleasure
# Skills Western Riding
# Skills Wife-Safe Horse
# Skills Working Equitation
# Skills Yearling
# Skills Youth
# Total rows 4842 Line  140
# Total rows 4842 Line  172
# N rows 4842
# /Users/jbrosamer/miniconda2/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
from model import *
df_test = all_data()
df = df_test.copy()
df = clean_col(df)
# Out:
# df.columns Index([u'id', u'breed', u'price', u'color', u'age', u'zip', u'temp',
#        u'warmblood', u'sold', u'soldhere',
#        ...
#        u'Two-Rein Horse', u'Vaulting', u'Weanling', u'Western Dressage',
#        u'Western Pleasure', u'Western Riding', u'Wife-Safe Horse',
#        u'Working Equitation', u'Yearling', u'Youth'],
#       dtype='object', length=184)

# %%
df = encode(df)
b = Model(df)
b.split()
b.kfold_cv(n_folds=2)
b.plot_results()
#df=b.cross_val_cols()
# Out:
# Score 0.407717260305
# Score 0.38385429156
# Abs Median Error: 1788.24933151
# Abs Percent Error: 0.408963692738
# Mean RMSE: 6060.77006932
# R2 0.395785775933
# Line fit m:0.450883 b:4.635340

# %%
from model import *
gbr=b.makeModel()
b.plotFeatures()
# Out:
# Feature ranking:
# breed 1. feature 4 (0.139165)
# age 2. feature 0 (0.137200)
# inches 3. feature 2 (0.095203)
# color 4. feature 3 (0.055961)
# Dressage 5. feature 39 (0.018251)
# Broodmare 6. feature 24 (0.017553)
# Trick Horse 139. feature 157 (0.000000)
# Three-In-One Package 140. feature 153 (0.000000)
# Two-Rein Horse 141. feature 161 (0.000000)
# Vaulting 142. feature 162 (0.000000)
# Turnback Horse 143. feature 159 (0.000000)
# Recipient Broodmare 144. feature 118 (0.000000)
# Companion Only 145. feature 30 (0.000000)
# Rodeo Pickup Horse 146. feature 129 (0.000000)
# Polocrosse 147. feature 108 (0.000000)
# Rescue Horse 148. feature 122 (0.000000)
# PMU Foal 149. feature 104 (0.000000)
# Park 150. feature 101 (0.000000)
# Orphan Foal 151. feature 97 (0.000000)
# Nurse Mare 152. feature 96 (0.000000)
# NRCHA Subscribed Stallion 153. feature 93 (0.000000)
# NRBC Eligible 154. feature 91 (0.000000)
# Longe Line 155. feature 83 (0.000000)
# Kentucky Breeders Incentive Program 156. feature 80 (0.000000)
# Rodeo Bronc 157. feature 128 (0.000000)
# Horse Ball 158. feature 69 (0.000000)
# Drill Team 159. feature 40 (0.000000)
# Homozygous Black 160. feature 66 (0.000000)
# High-Percentage Dun Factor Producer 161. feature 64 (0.000000)
# High-Percentage Cropout Producer 162. feature 63 (0.000000)
# HERDA N-N 163. feature 60 (0.000000)
# Hazing 164. feature 58 (0.000000)
# Harness Racing 165. feature 57 (0.000000)
# Guard Donkey 166. feature 51 (0.000000)
# GBED N-N 167. feature 50 (0.000000)
# GBED N-G 168. feature 49 (0.000000)
# School 169. feature 134 (0.000000)
# Show Hack 170. feature 137 (0.000000)
# HERDA N-Hrd 171. feature 59 (0.000000)

# %%
b.plotPartial(8)
# Out:
# features [ 4  0  2  3 39 24 79  5]
# FeatureNames ['age', 'gender', 'inches', 'color', 'breed', 'registered', 'dressage', 'hunt', 'jump', 'event', 'prospect', 'import', 'compet', 'video', '4H', '5-Panel DNA Test N-N', 'Advanced Rider Recommended', 'Agility', 'All Around', 'Baroque Horse', 'Barrel Racing', 'Beginner-Safe Horse', 'Breeders Trust', 'Bridle Horse', 'Broodmare', 'Broodmare Only', 'Calf Roping', 'Champion', 'Champion Pedigree', 'Color Tested', 'Companion Only', 'Country English Pleasure', 'Cowboy Mounted Shooting', 'Cowboy Racing', 'Cowhorse', 'Cutting', 'Double Registered', 'Double Registered AQHA-APHA', 'Draft', 'Dressage', 'Drill Team', 'Driving', 'Endurance Riding', 'English Pleasure', 'Eventing', 'Field Trials', 'Foundation Bred', 'Foxhunter', 'Futurity Eligible', 'GBED N-G', 'GBED N-N', 'Guard Donkey', 'Gun-Safe Hunting Horse', 'Gymkhana', 'Hackamore Horse', 'Halter', 'Harness', 'Harness Racing', 'Hazing', 'HERDA N-Hrd', 'HERDA N-N', 'Heterozygous', 'High-Percentage Color Producer', 'High-Percentage Cropout Producer', 'High-Percentage Dun Factor Producer', 'Homozygous', 'Homozygous Black', 'Homozygous Roan', 'Homozygous Tobiano', 'Horse Ball', 'Horsemanship', 'Hunt Seat Equitation', 'Hunter', 'Hunter Under Saddle', 'Husband-Safe Horse', 'HYPP N-H', 'HYPP N-N', 'Incentive Fund', 'Intermediate Rider Recommended', 'Jumping', 'Kentucky Breeders Incentive Program', 'Kid-Friendly Family Horse', 'Lesson Horse', 'Longe Line', 'Money Winner', 'Mounted Games', 'Mounted Patrol', 'Mounted Police', 'Native Costume', 'Natural Horsemanship Training', 'No Vices', 'NRBC Eligible', 'NRBC Enrolled', 'NRCHA Subscribed Stallion', 'NRHA Futurity-Derby Nominated', 'NRHA Sire and Dam Program', 'Nurse Mare', 'Orphan Foal', 'Pacing Gait', 'Pack Horse', 'Parades', 'Park', 'Playday', 'Pleasure Driving', 'PMU Foal', 'Point Earner', 'Pole Bending', 'Polo', 'Polocrosse', 'Pony Breed', 'Pony Club', 'Racing', 'Racing, Retired Racehorse', 'Racking Gait', 'Ranch Horse Riding', 'Ranch Sorting', 'Ranch Versatility', 'Ranch Work', 'Recipient Broodmare', 'Register of Merit', 'Reining', 'Reining Cowhorse Cutting', 'Rescue Horse', 'Ridden English', 'Ridden Western', 'Rider Level: Amateur', 'Rider Level: Novice', 'Rider Level: Open', 'Rodeo Bronc', 'Rodeo Pickup Horse', 'Rodeo Queen Horse', 'Roping', 'Roping, All Around', 'Saddle Seat', 'School', 'Schoolmaster', 'Show Experience', 'Show Hack', 'Show Winner', 'Showmanship at Halter', 'Sidesaddle', 'Sporthorse', 'Stallion, Breeding', 'Started Under Saddle', 'Steer Roping', 'Steer Wrestling', 'Superior Award', 'Team Driving', 'Team Penning', 'Team Roping', 'Team Roping Head Horse', 'Team Roping Heel Horse', 'Therapeutic Riding', 'Three-In-One Package', 'Trail Class Competition', 'Trail Riding, Competitive', 'Trail Riding, Recreational', 'Trick Horse', 'Triple Registered', 'Turnback Horse', 'Two-In-One Package', 'Two-Rein Horse', 'Vaulting', 'Weanling', 'Western Dressage', 'Western Pleasure', 'Western Riding', 'Wife-Safe Horse', 'Working Equitation', 'Yearling', 'Youth', 'lnprice']
# ________________________________________________________________________________
# Custom 3d plot via ``partial_dependence``

# %%
features=final_cols[:-1]
medians=list()
means=list()
pf=predCVDataframe()
gpDict=dict()
for f in features:
    gpBy=pf.groupby(pf[f])['perDiff'].median().sort_values(ascending=False)
    gpDict[f]=gpBy
# Out:
# df.columns Index([u'id', u'breed', u'price', u'color', u'age', u'zip', u'temp',
#        u'warmblood', u'sold', u'soldhere',
#        ...
#        u'Two-Rein Horse', u'Vaulting', u'Weanling', u'Western Dressage',
#        u'Western Pleasure', u'Western Riding', u'Wife-Safe Horse',
#        u'Working Equitation', u'Yearling', u'Youth'],
#       dtype='object', length=184)

# %%
gpDict['breedGroup']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-59bbf44329cf> in <module>()
# ----> 1 gpDict['breedGroup']
#
# KeyError: 'breedGroup'

# %%
plt.style.use('ggplot')
df = df_test.copy()
df = clean_col(df)
idx = df.loc[df['price']>100000,:].index
#df = df.drop(idx, axis = 0)
df_temp = df[['age','inches', 'gender', 'lnprice']]
plot = sns.pairplot(df_temp, hue = 'gender', diag_kind='kde')
