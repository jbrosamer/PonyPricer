# %%
# %load_ext autoreload
# %autoreload 2
# %cd ~/PonyPricer/
import scraper as s
import pandas as pd
ad=s.scrapeAd(1956256)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /Users/jbrosamer/PonyPricer
#  colName zip 2
# colName breed 4
# colName age 6
# colName gender 8
# colName height 10
# Ex list index out of range
# adDict {'warmblood': None, 'temp': None, 'zip': '56353', 'breedStr': u'\nAQHA Quarter Horse\xa0\nFoundation Quarter Horse Registry FQHR\xa0\nRelated Searches by Breed\n', 'color': None, 'gender': u'Mare', 'price': None, 'breed': 'Foundation Quarter Horse Registry FQHR', 'registered': None, 'skills': None, 'height': None, 'age': 17.753424657534246, 'location': u'Milaca Minnesota 56353', 'sold': False, 'forlease': None, 'forsale': None, 'soldhere': False, 'id': 1956256, 'desc': None}

# %%
tables=ad.findAll(name="table")
cells=tables[3].findAll("td")

# %%
cells2=tables[4].findAll("td")

# %%
cells2
# Out:
# [<td>\n<table border="1" bordercolor="black" cellpadding="1" cellspacing="0" style="border-collapse: collapse;" width="100%">\n<tr>\n<td class="sire" rowspan="8" width="20%">\n<b>Sire:</b><br>\n<a href="http://www.dreamhorse.com/bloodline_search.php?form_generation=4&amp;form_position=CONTAINS&amp;form_at_stud_yn=N&amp;form_for_sale_yn=Y&amp;form_bloodline=Watch+Tonys+Satchel&amp;form_breed_id=39">\n<img alt="Bloodline Search" border="0" height="16" src="http://www.dreamhorse.com/images/magnifier.png" width="16"/></a>\xa0\n\nWatch Tonys Satchel\n    </br></td>\n<td class="sire" rowspan="4" width="20%">\n<a href="http://www.dreamhorse.com/bloodline_search.php?form_generation=4&amp;form_position=CONTAINS&amp;form_at_stud_yn=N&amp;form_for_sale_yn=Y&amp;form_bloodline=Watch+Joe+Tony&amp;form_breed_id=39">\n<img alt="Bloodline Search" border="0" height="16" src="http://www.dreamhorse.com/images/magnifier.png" width="16"/></a>\xa0\n\nWatch Joe Tony\xa0    </td>\n<td class="sire" rowspan="
# ...
